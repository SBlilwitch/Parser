# %%
from lib import schedule_parser


final_result=schedule_parser.transform('input data/test_schedule.inc')
display(final_result)
# Out:
#            Date Well name Local grid name   I   J K upper K lower  \
# 0                                      W1  10  10       1       3
# 1                                      W2  32  10       1       3
# 2                                      W3   5  36       2       2
# 3                                      W4  40  30       1       3
# 4                                      W5  21  21       4       4
# 5   01 JUN 2018
# 6   01 JUL 2018
# 7   01 JUL 2018                        W3  32  10       1       1
# 8   01 JUL 2018                        W5  21  21       1       3
# 9   01 AUG 2018
# 10  01 SEP 2018
# 11  01 SEP 2018                        W1  10  10       2       3
# 12  01 SEP 2018                        W2  32  10       1       2
# 13  01 SEP 2018      LGR1              W3  10  10       2       2
# 14  01 OCT 2018
# 15  01 NOV 2018
# 16  01 DEC 2018
#
#    Flag on connection Saturation table Transmissibility factor  \
# ...
